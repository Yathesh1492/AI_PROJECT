# %% [markdown]
# # Importing Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Datasets

# %%
dataset = pd.read_csv('heart.csv')

# %%
dataset
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (303, 14)

# %%
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
dataset.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]
for i in range(len(info)):
    print(dataset.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
dataset["target"].describe()
# Out:
# count    303.000000
# mean       0.544554
# std        0.498835
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
dataset["target"].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# # Correlation between features of dataset

# %%
dataset.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# target   -0.225439 -0.280937  0.433798 -0.144931 -0.085239 -0.028046
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.116211 -0.398522  0.096801  0.210013 -0.168814  0.276326
# sex      -0.058196 -0.044020  0.141664  0.096093 -0.030711  0.118261
# cp        0.044421  0.295762 -0.394280 -0.149230  0.119717 -0.181053
# trestbps -0.114103 -0.046698  0.067616  0.193216 -0.121475  0.101389
# chol     -0.151040 -0.009940  0.067023  0.053952 -0.004038  0.070511
# fbs      -0.084189 -0.008567  0.025665  0.005747 -0.059894  0.137979
# restecg   1.000000  0.044123 -0.070733 -0.058770  0.093045 -0.072042
# thalach   0.044123  1.000000 -0.378812 -0.344187  0.386784 -0.213177
# exang    -0.070733 -0.378812  1.000000  0.288223 -0.257748  0.115739
# oldpeak  -0.058770 -0.344187  0.288223  1.000000 -0.577537  0.222682
# slope     0.093045  0.386784 -0.257748 -0.577537  1.000000 -0.080155
# ca       -0.072042 -0.213177  0.115739  0.222682 -0.080155  1.000000
# thal     -0.011981 -0.096439  0.206754  0.210244 -0.104764  0.151832
# target    0.137230  0.421741 -0.436757 -0.430696  0.345877 -0.391724
#
#               thal    target
# age       0.068001 -0.225439
# sex       0.210041 -0.280937
# cp       -0.161736  0.433798
# trestbps  0.062210 -0.144931
# chol      0.098803 -0.085239
# fbs      -0.032019 -0.028046
# restecg  -0.011981  0.137230
# thalach  -0.096439  0.421741
# exang     0.206754 -0.436757
# oldpeak   0.210244 -0.430696
# slope    -0.104764  0.345877
# ca        0.151832 -0.391724
# thal      1.000000 -0.344029
# target   -0.344029  1.000000

# %%
sns.heatmap(dataset.corr(),vmin=0, vmax=0.5)
# Out:
# <AxesSubplot:>

# %%
dataset.groupby("cp").mean()
# Out:
#           age       sex    trestbps        chol       fbs   restecg  \
# cp
# 0   55.692308  0.727273  132.020979  250.132867  0.125874  0.475524
# 1   51.360000  0.640000  128.400000  244.780000  0.100000  0.620000
# 2   53.517241  0.597701  130.379310  243.172414  0.195402  0.597701
# 3   55.869565  0.826087  140.869565  237.130435  0.217391  0.391304
#
#        thalach     exang   oldpeak     slope        ca      thal    target
# cp
# 0   140.538462  0.559441  1.383217  1.258741  0.965035  2.447552  0.272727
# 1   162.420000  0.080000  0.316000  1.680000  0.420000  2.140000  0.820000
# 2   155.609195  0.126437  0.797701  1.505747  0.586207  2.206897  0.793103
# 3   155.956522  0.173913  1.391304  1.260870  0.478261  2.260870  0.695652

# %%
pd.crosstab(dataset['age'],dataset['target'])
# Out:
# target   0   1
# age
# 29       0   1
# 34       0   2
# 35       2   2
# 37       0   2
# 38       1   2
# 39       1   3
# 40       2   1
# 41       1   9
# 42       1   7
# 43       3   5
# 44       3   8
# 45       2   6
# 46       3   4
# 47       2   3
# 48       3   4
# 49       2   3
# 50       3   4
# 51       3   9
# 52       4   9
# 53       2   6
# 54       6  10
# 55       5   3
# 56       6   5
# 57      10   7
# 58      12   7
# 59       9   5
# 60       8   3
# 61       7   1
# 62       7   4
# 63       6   3
# 64       4   6
# 65       4   4
# 66       3   4
# 67       6   3
# 68       2   2
# 69       1   2
# 70       3   1
# 71       0   3
# 74       0   1
# 76       0   1
# 77       1   0

# %%
print(dataset.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# exang       0.436757
# cp          0.433798
# oldpeak     0.430696
# thalach     0.421741
# ca          0.391724
# slope       0.345877
# thal        0.344029
# sex         0.280937
# age         0.225439
# trestbps    0.144931
# restecg     0.137230
# chol        0.085239
# fbs         0.028046
# Name: target, dtype: float64

# %% [markdown]
# # Data Visualizations

# %%
y = dataset["target"]
sns.countplot(y)
z = dataset.target.value_counts()
print(z)
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print("Percentage of patience without having heart problems: "+str(round(z[0]*100/303,2)))
print("Percentage of patience with heart problems: "+str(round(z[1]*100/303,2)))
# Out:
# Percentage of patience without having heart problems: 45.54
# Percentage of patience with heart problems: 54.46

# %%
dataset["sex"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.barplot(dataset["sex"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='target'>

# %%
dataset["cp"].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
sns.barplot(dataset["cp"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cp', ylabel='target'>

# %%
dataset["fbs"].describe()
# Out:
# count    303.000000
# mean       0.148515
# std        0.356198
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fbs, dtype: float64

# %%
dataset["fbs"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.barplot(dataset["fbs"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fbs', ylabel='target'>

# %%
dataset["cp"].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
sns.barplot(dataset["cp"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cp', ylabel='target'>

# %%
dataset["fbs"].describe()
# Out:
# count    303.000000
# mean       0.148515
# std        0.356198
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fbs, dtype: float64

# %%
dataset["fbs"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
dataset["restecg"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
sns.barplot(dataset["restecg"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='restecg', ylabel='target'>

# %%
dataset["exang"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.barplot(dataset["exang"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='exang', ylabel='target'>

# %%
dataset["slope"].unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %%
sns.barplot(dataset["slope"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='slope', ylabel='target'>

# %%
dataset["ca"].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
sns.countplot(dataset["ca"])
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %%
sns.barplot(dataset["ca"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ca', ylabel='target'>

# %%
dataset["thal"].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
sns.barplot(dataset["thal"],y)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='thal', ylabel='target'>

# %%
sns.distplot(dataset["thal"])
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='thal', ylabel='Density'>

# %%
sns.pairplot(dataset)

# %% [markdown]
# # Data Splitted into Training, Validation and Testing

# %%
from sklearn.model_selection import train_test_split
predictor = dataset.drop("target",axis=1)
target = dataset["target"]
X_train,X_test,Y_train,Y_test = train_test_split(predictor,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (242, 13)

# %%
X_test.shape
# Out:
# (61, 13)

# %%
Y_train.shape
# Out:
# (242,)

# %%
Y_test.shape
# Out:
# (61,)

# %% [markdown]
# # Logistic Regression Model

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,Y_train)
Y_pred_lr = lr.predict(X_test)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Y_pred_lr.shape
# Out:
# (61,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)
print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,Y_train)
Y_pred_nb = nb.predict(X_test)
Y_pred_nb.shape
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)
print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 85.25 %

# %% [markdown]
# # Linear Support Vector Machine(SVM)

# %%
from sklearn import svm
sv = svm.SVC(kernel='linear')
sv.fit(X_train, Y_train)
Y_pred_svm = sv.predict(X_test)
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)
print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 81.97 %

# %% [markdown]
# # K Nearest Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)
print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 67.21 %

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=0)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)
print(Y_pred_dt.shape)
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# (61,)
# The accuracy score achieved using Decision Tree is: 78.69 %

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
print("The accuracy score achieved using Random Forest is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Random Forest is: 88.52 %

# %% [markdown]
# # Neutral Network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 1s 2ms/step - loss: 58.5835 - accuracy: 0.4587
# Epoch 2/300
# 8/8 [==============================] - 0s 2ms/step - loss: 54.1932 - accuracy: 0.4587
# Epoch 3/300
# 8/8 [==============================] - 0s 3ms/step - loss: 50.0162 - accuracy: 0.4587
# Epoch 4/300
# 8/8 [==============================] - 0s 2ms/step - loss: 46.2678 - accuracy: 0.4587
# Epoch 5/300
# 8/8 [==============================] - 0s 2ms/step - loss: 42.4505 - accuracy: 0.4587
# Epoch 6/300
# 8/8 [==============================] - 0s 2ms/step - loss: 38.9881 - accuracy: 0.4587
# Epoch 7/300
# 8/8 [==============================] - 0s 2ms/step - loss: 35.5640 - accuracy: 0.4587
# Epoch 8/300
# 8/8 [==============================] - 0s 870us/step - loss: 32.3944 - accuracy: 0.4587
# Epoch 9/300
# 8/8 [==============================] - 0s 2ms/step - loss: 29.1256 - accuracy: 0.4587
# Epoch 10/300
# 8/8 [==============================] - 0s 2ms/step - loss: 26.0450 - accuracy: 0.4587
# Epoch 11/300
# 8/8 [==============================] - 0s 2ms/step - loss: 22.8879 - accuracy: 0.4587
# Epoch 12/300
# 8/8 [==============================] - 0s 1ms/step - loss: 19.9003 - accuracy: 0.4587
# Epoch 13/300
# 8/8 [==============================] - 0s 2ms/step - loss: 16.7740 - accuracy: 0.4587
# Epoch 14/300
# 8/8 [==============================] - 0s 1ms/step - loss: 13.7757 - accuracy: 0.4587
# Epoch 15/300
# 8/8 [==============================] - 0s 3ms/step - loss: 10.6477 - accuracy: 0.4587
# Epoch 16/300
# 8/8 [==============================] - 0s 2ms/step - loss: 7.5688 - accuracy: 0.4587
# Epoch 17/300
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4495 - accuracy: 0.4587
# Epoch 18/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.6283 - accuracy: 0.5124
# Epoch 19/300
# 8/8 [==============================] - 0s 981us/step - loss: 0.9116 - accuracy: 0.6157
# Epoch 20/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0794 - accuracy: 0.6116
# Epoch 21/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8422 - accuracy: 0.6033
# Epoch 22/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7751 - accuracy: 0.6240
# Epoch 23/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7804 - accuracy: 0.6281
# Epoch 24/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7580 - accuracy: 0.6281
# Epoch 25/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7487 - accuracy: 0.6446
# Epoch 26/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7446 - accuracy: 0.6694
# Epoch 27/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7481 - accuracy: 0.6488
# Epoch 28/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7387 - accuracy: 0.6529
# Epoch 29/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7369 - accuracy: 0.6570
# Epoch 30/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.7350 - accuracy: 0.6529
# Epoch 31/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.7300 - accuracy: 0.6612
# Epoch 32/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7287 - accuracy: 0.6529
# Epoch 33/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7252 - accuracy: 0.6529
# Epoch 34/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7238 - accuracy: 0.6653
# Epoch 35/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7195 - accuracy: 0.6653
# Epoch 36/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7164 - accuracy: 0.6612
# Epoch 37/300
# 8/8 [==============================] - 0s 654us/step - loss: 0.7158 - accuracy: 0.6860
# Epoch 38/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7122 - accuracy: 0.6777
# Epoch 39/300
# 8/8 [==============================] - 0s 422us/step - loss: 0.7098 - accuracy: 0.6612
# Epoch 40/300
# 8/8 [==============================] - 0s 394us/step - loss: 0.7063 - accuracy: 0.6653
# Epoch 41/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.7050 - accuracy: 0.6653
# Epoch 42/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7008 - accuracy: 0.6612
# Epoch 43/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7003 - accuracy: 0.6570
# Epoch 44/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7016 - accuracy: 0.6694
# Epoch 45/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6934 - accuracy: 0.6694
# Epoch 46/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.6694
# Epoch 47/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6888 - accuracy: 0.6612
# Epoch 48/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.6694
# Epoch 49/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6813 - accuracy: 0.6694
# Epoch 50/300
# 8/8 [==============================] - 0s 758us/step - loss: 0.6780 - accuracy: 0.6736
# Epoch 51/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6750 - accuracy: 0.6736
# Epoch 52/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6697 - accuracy: 0.6736
# Epoch 53/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6671 - accuracy: 0.6777
# Epoch 54/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6672 - accuracy: 0.6736
# Epoch 55/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6582 - accuracy: 0.6777
# Epoch 56/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6524 - accuracy: 0.6777
# Epoch 57/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6503 - accuracy: 0.6777
# Epoch 58/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6483 - accuracy: 0.6736
# Epoch 59/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6471 - accuracy: 0.6777
# Epoch 60/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6458 - accuracy: 0.6777
# Epoch 61/300
# 8/8 [==============================] - 0s 606us/step - loss: 0.6426 - accuracy: 0.6777
# Epoch 62/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6427 - accuracy: 0.6736
# Epoch 63/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6407 - accuracy: 0.6818
# Epoch 64/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6373 - accuracy: 0.6860
# Epoch 65/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6356 - accuracy: 0.6777
# Epoch 66/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6347 - accuracy: 0.6777
# Epoch 67/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6308 - accuracy: 0.6860
# Epoch 68/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6291 - accuracy: 0.6777
# Epoch 69/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6303 - accuracy: 0.6818
# Epoch 70/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6251 - accuracy: 0.6818
# Epoch 71/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6261 - accuracy: 0.6777
# Epoch 72/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6251 - accuracy: 0.6694
# Epoch 73/300
# 8/8 [==============================] - 0s 521us/step - loss: 0.6183 - accuracy: 0.6818
# Epoch 74/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6212 - accuracy: 0.6860
# Epoch 75/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6204 - accuracy: 0.6736
# Epoch 76/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6167 - accuracy: 0.6777
# Epoch 77/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6157 - accuracy: 0.6860
# Epoch 78/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6116 - accuracy: 0.6818
# Epoch 79/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6114 - accuracy: 0.6777
# Epoch 80/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6108 - accuracy: 0.6901
# Epoch 81/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6081 - accuracy: 0.6818
# Epoch 82/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6173 - accuracy: 0.6570
# Epoch 83/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6087 - accuracy: 0.6736
# Epoch 84/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6049 - accuracy: 0.6860
# Epoch 85/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6056 - accuracy: 0.6694
# Epoch 86/300
# 8/8 [==============================] - 0s 698us/step - loss: 0.6031 - accuracy: 0.6818
# Epoch 87/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5987 - accuracy: 0.6901
# Epoch 88/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5982 - accuracy: 0.6818
# Epoch 89/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5969 - accuracy: 0.6901
# Epoch 90/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5969 - accuracy: 0.6983
# Epoch 91/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5936 - accuracy: 0.6942
# Epoch 92/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5942 - accuracy: 0.6942
# Epoch 93/300
# 8/8 [==============================] - 0s 505us/step - loss: 0.5894 - accuracy: 0.6818
# Epoch 94/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5894 - accuracy: 0.6901
# Epoch 95/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5882 - accuracy: 0.6777
# Epoch 96/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5850 - accuracy: 0.7025
# Epoch 97/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5850 - accuracy: 0.6942
# Epoch 98/300
# 8/8 [==============================] - 0s 934us/step - loss: 0.5832 - accuracy: 0.6942
# Epoch 99/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5820 - accuracy: 0.6983
# Epoch 100/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5805 - accuracy: 0.7025
# Epoch 101/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5811 - accuracy: 0.7107
# Epoch 102/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5853 - accuracy: 0.6942
# Epoch 103/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5744 - accuracy: 0.6942
# Epoch 104/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5783 - accuracy: 0.7149
# Epoch 105/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5723 - accuracy: 0.7066
# Epoch 106/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5737 - accuracy: 0.6983
# Epoch 107/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5710 - accuracy: 0.6901
# Epoch 108/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5713 - accuracy: 0.6983
# Epoch 109/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5692 - accuracy: 0.7149
# Epoch 110/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5676 - accuracy: 0.6860
# Epoch 111/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5686 - accuracy: 0.6942
# Epoch 112/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5629 - accuracy: 0.6983
# Epoch 113/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5649 - accuracy: 0.6942
# Epoch 114/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5762 - accuracy: 0.7190
# Epoch 115/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5598 - accuracy: 0.7066
# Epoch 116/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5616 - accuracy: 0.6901
# Epoch 117/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.5637 - accuracy: 0.7190
# Epoch 118/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5592 - accuracy: 0.7025
# Epoch 119/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5536 - accuracy: 0.7066
# Epoch 120/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5526 - accuracy: 0.7190
# Epoch 121/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5547 - accuracy: 0.7149
# Epoch 122/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5525 - accuracy: 0.7149
# Epoch 123/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5500 - accuracy: 0.7107
# Epoch 124/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5468 - accuracy: 0.7231
# Epoch 125/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5469 - accuracy: 0.7190
# Epoch 126/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.7273
# Epoch 127/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5448 - accuracy: 0.7273
# Epoch 128/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.7273
# Epoch 129/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.7190
# Epoch 130/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5517 - accuracy: 0.7190
# Epoch 131/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5426 - accuracy: 0.7314
# Epoch 132/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5387 - accuracy: 0.7273
# Epoch 133/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5390 - accuracy: 0.7314
# Epoch 134/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5351 - accuracy: 0.7355
# Epoch 135/300
# 8/8 [==============================] - 0s 82us/step - loss: 0.5331 - accuracy: 0.7397
# Epoch 136/300
# 8/8 [==============================] - 0s 827us/step - loss: 0.5356 - accuracy: 0.7314
# Epoch 137/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.7397
# Epoch 138/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.5320 - accuracy: 0.7479
# Epoch 139/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5294 - accuracy: 0.7355
# Epoch 140/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5259 - accuracy: 0.7438
# Epoch 141/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5291 - accuracy: 0.7479
# Epoch 142/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5253 - accuracy: 0.7479
# Epoch 143/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5213 - accuracy: 0.7397
# Epoch 144/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5254 - accuracy: 0.7314
# Epoch 145/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5273 - accuracy: 0.7397
# Epoch 146/300
# 8/8 [==============================] - 0s 568us/step - loss: 0.5225 - accuracy: 0.7355
# Epoch 147/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.7521
# Epoch 148/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5184 - accuracy: 0.7397
# Epoch 149/300
# 8/8 [==============================] - 0s 72us/step - loss: 0.5196 - accuracy: 0.7438
# Epoch 150/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5137 - accuracy: 0.7438
# Epoch 151/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.5175 - accuracy: 0.7479
# Epoch 152/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5125 - accuracy: 0.7438
# Epoch 153/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5185 - accuracy: 0.7479
# Epoch 154/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5131 - accuracy: 0.7603
# Epoch 155/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5107 - accuracy: 0.7521
# Epoch 156/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.7479
# Epoch 157/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7438
# Epoch 158/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5112 - accuracy: 0.7521
# Epoch 159/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.7438
# Epoch 160/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.5040 - accuracy: 0.7562
# Epoch 161/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.7562
# Epoch 162/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5017 - accuracy: 0.7645
# Epoch 163/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5027 - accuracy: 0.7438
# Epoch 164/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4984 - accuracy: 0.7562
# Epoch 165/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.4996 - accuracy: 0.7562
# Epoch 166/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5020 - accuracy: 0.7479
# Epoch 167/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4989 - accuracy: 0.7562
# Epoch 168/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4963 - accuracy: 0.7562
# Epoch 169/300
# 8/8 [==============================] - 0s 598us/step - loss: 0.4960 - accuracy: 0.7603
# Epoch 170/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4940 - accuracy: 0.7521
# Epoch 171/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4935 - accuracy: 0.7479
# Epoch 172/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.4960 - accuracy: 0.7603
# Epoch 173/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4935 - accuracy: 0.7603
# Epoch 174/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7438
# Epoch 175/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4901 - accuracy: 0.7686
# Epoch 176/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4892 - accuracy: 0.7727
# Epoch 177/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4912 - accuracy: 0.7562
# Epoch 178/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4972 - accuracy: 0.7727
# Epoch 179/300
# 8/8 [==============================] - 0s 459us/step - loss: 0.4926 - accuracy: 0.7521
# Epoch 180/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4896 - accuracy: 0.7562
# Epoch 181/300
# 8/8 [==============================] - 0s 92us/step - loss: 0.4830 - accuracy: 0.7769
# Epoch 182/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4857 - accuracy: 0.7438
# Epoch 183/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4797 - accuracy: 0.7645
# Epoch 184/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4864 - accuracy: 0.7810
# Epoch 185/300
# 8/8 [==============================] - 0s 72us/step - loss: 0.4805 - accuracy: 0.7645
# Epoch 186/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4862 - accuracy: 0.7810
# Epoch 187/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4823 - accuracy: 0.7479
# Epoch 188/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4791 - accuracy: 0.7645
# Epoch 189/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4771 - accuracy: 0.7686
# Epoch 190/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4761 - accuracy: 0.7769
# Epoch 191/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4746 - accuracy: 0.7686
# Epoch 192/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4753 - accuracy: 0.7686
# Epoch 193/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4730 - accuracy: 0.7769
# Epoch 194/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4745 - accuracy: 0.7727
# Epoch 195/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.7769
# Epoch 196/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.7562
# Epoch 197/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4753 - accuracy: 0.7851
# Epoch 198/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.7686
# Epoch 199/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.7645
# Epoch 200/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4677 - accuracy: 0.7851
# Epoch 201/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4665 - accuracy: 0.7727
# Epoch 202/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.7686
# Epoch 203/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4662 - accuracy: 0.7851
# Epoch 204/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4705 - accuracy: 0.7769
# Epoch 205/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4733 - accuracy: 0.7645
# Epoch 206/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.7810
# Epoch 207/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.7810
# Epoch 208/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.7810
# Epoch 209/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4722 - accuracy: 0.7562
# Epoch 210/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4805 - accuracy: 0.7810
# Epoch 211/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.7727
# Epoch 212/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.7851
# Epoch 213/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4627 - accuracy: 0.7851
# Epoch 214/300
# 8/8 [==============================] - 0s 767us/step - loss: 0.4608 - accuracy: 0.7851
# Epoch 215/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4569 - accuracy: 0.7893
# Epoch 216/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4575 - accuracy: 0.7934
# Epoch 217/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4560 - accuracy: 0.7851
# Epoch 218/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4551 - accuracy: 0.7851
# Epoch 219/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.7851
# Epoch 220/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4565 - accuracy: 0.7769
# Epoch 221/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.7934
# Epoch 222/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4522 - accuracy: 0.7851
# Epoch 223/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4567 - accuracy: 0.7893
# Epoch 224/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4499 - accuracy: 0.7893
# Epoch 225/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4508 - accuracy: 0.8017
# Epoch 226/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4551 - accuracy: 0.7810
# Epoch 227/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4478 - accuracy: 0.8017
# Epoch 228/300
# 8/8 [==============================] - 0s 497us/step - loss: 0.4496 - accuracy: 0.7810
# Epoch 229/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4508 - accuracy: 0.7975
# Epoch 230/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4448 - accuracy: 0.8140
# Epoch 231/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4555 - accuracy: 0.7934
# Epoch 232/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.7893
# Epoch 233/300
# 8/8 [==============================] - 0s 748us/step - loss: 0.4484 - accuracy: 0.7769
# Epoch 234/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4461 - accuracy: 0.7893
# Epoch 235/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.7975
# Epoch 236/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4431 - accuracy: 0.8017
# Epoch 237/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.4417 - accuracy: 0.8017
# Epoch 238/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4454 - accuracy: 0.8017
# Epoch 239/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4427 - accuracy: 0.7975
# Epoch 240/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4403 - accuracy: 0.8058
# Epoch 241/300
# 8/8 [==============================] - 0s 397us/step - loss: 0.4403 - accuracy: 0.8017
# Epoch 242/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.7893
# Epoch 243/300
# 8/8 [==============================] - 0s 493us/step - loss: 0.4365 - accuracy: 0.7975
# Epoch 244/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4394 - accuracy: 0.8017
# Epoch 245/300
# 8/8 [==============================] - 0s 966us/step - loss: 0.4421 - accuracy: 0.7893
# Epoch 246/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4437 - accuracy: 0.7851
# Epoch 247/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4505 - accuracy: 0.7810
# Epoch 248/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.8099
# Epoch 249/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4376 - accuracy: 0.8017
# Epoch 250/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4373 - accuracy: 0.7934
# Epoch 251/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.8099
# Epoch 252/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4331 - accuracy: 0.8058
# Epoch 253/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4335 - accuracy: 0.8099
# Epoch 254/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4340 - accuracy: 0.8058
# Epoch 255/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4358 - accuracy: 0.8058
# Epoch 256/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.7934
# Epoch 257/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4339 - accuracy: 0.8099
# Epoch 258/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.4307 - accuracy: 0.8058
# Epoch 259/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.8099
# Epoch 260/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4342 - accuracy: 0.8140
# Epoch 261/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4296 - accuracy: 0.8058
# Epoch 262/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4294 - accuracy: 0.8058
# Epoch 263/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4354 - accuracy: 0.8017
# Epoch 264/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.7934
# Epoch 265/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4286 - accuracy: 0.8058
# Epoch 266/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.7934
# Epoch 267/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.8182
# Epoch 268/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4261 - accuracy: 0.8140
# Epoch 269/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4252 - accuracy: 0.8099
# Epoch 270/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4246 - accuracy: 0.8182
# Epoch 271/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4407 - accuracy: 0.7851
# Epoch 272/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4387 - accuracy: 0.7934
# Epoch 273/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4320 - accuracy: 0.8017
# Epoch 274/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4275 - accuracy: 0.7975
# Epoch 275/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4228 - accuracy: 0.8140
# Epoch 276/300
# 8/8 [==============================] - 0s 71us/step - loss: 0.4247 - accuracy: 0.8099
# Epoch 277/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8058
# Epoch 278/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4245 - accuracy: 0.8182
# Epoch 279/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.8182
# Epoch 280/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4245 - accuracy: 0.8099
# Epoch 281/300
# 8/8 [==============================] - 0s 76us/step - loss: 0.4343 - accuracy: 0.8017
# Epoch 282/300
# 8/8 [==============================] - 0s 367us/step - loss: 0.4212 - accuracy: 0.8099
# Epoch 283/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4193 - accuracy: 0.8099
# Epoch 284/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8140
# Epoch 285/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4186 - accuracy: 0.8182
# Epoch 286/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4193 - accuracy: 0.8182
# Epoch 287/300
# 8/8 [==============================] - 0s 0s/step - loss: 0.4148 - accuracy: 0.8182
# Epoch 288/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4232 - accuracy: 0.8017
# Epoch 289/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4199 - accuracy: 0.8223
# Epoch 290/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4354 - accuracy: 0.8058
# Epoch 291/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4180 - accuracy: 0.8306
# Epoch 292/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4103 - accuracy: 0.8264
# Epoch 293/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8099
# Epoch 294/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.8099
# Epoch 295/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4121 - accuracy: 0.8099
# Epoch 296/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.8264
# Epoch 297/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4039 - accuracy: 0.8223
# Epoch 298/300
# 8/8 [==============================] - 0s 981us/step - loss: 0.4041 - accuracy: 0.8182
# Epoch 299/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8058
# Epoch 300/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.8264

# %%
Y_pred_nn = model.predict(X_test)
Y_pred_nn.shape
# Out:
# 2/2 [==============================] - 0s 0s/step
# (61, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]
Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)
print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")
# Out:
# The accuracy score achieved using Neural Network is: 80.33 %

# %% [markdown]
# # Comparing Models

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","Neutral Network"]    
for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %
# The accuracy score achieved using Naive Bayes is: 85.25 %
# The accuracy score achieved using Support Vector Machine is: 81.97 %
# The accuracy score achieved using K-Nearest Neighbors is: 67.21 %
# The accuracy score achieved using Decision Tree is: 78.69 %
# The accuracy score achieved using Random Forest is: 88.52 %
# The accuracy score achieved using Neutral Network is: 80.33 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")
sns.barplot(algorithms,scores)
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Algorithms', ylabel='Accuracy score'>

# %% [markdown]
# # Predicting the heart disease using a sample data

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2)

input_data_as_numpy_array= np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# 1/1 [==============================] - 0s 63ms/step
# The Person has Heart Disease
